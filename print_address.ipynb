# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
# Import "Owners Assistance" spreadsheet
owner_assist = './data/FEMA_Housing_Assistance_Owners.csv'
OA_df = pd.read_csv(owner_assist, low_memory=False, thousands = ',')
OAt_df = OA_df.sort_values(["Disaster", "Zip Code"])
OAt_df

# Only include inputs that can be summed or are part of the grouping
OAt_df["Disaster"] = OAt_df["Disaster"].astype(str)
OAt_df["address"] = OAt_df["Disaster"] + ', ' + OAt_df["State"] + ', ' + OAt_df["County"]

output_data_file1 = './data/FEMA_Housing_Assistance_Owners2.csv'
OAt_df.to_csv(output_data_file1, index=False, header=True)
OAt_df
# Out:
#       Disaster State              County               City  Zip Code  \
# 25394     4116    IL       Cook (County)           HILLSIDE     50162
# 25678     4116    IL       Lake (County)            ANTIOCH     60002
# 25276     4116    IL       Cook (County)  ARLINGTON HEIGHTS     60004
# 25277     4116    IL       Cook (County)  ARLINGTON HEIGHTS     60005
# 25369     4116    IL       Cook (County)  ELK GROVE VILLAGE     60007
# ...        ...   ...                 ...                ...       ...
# 26986     4466    TX  Jefferson (County)           BEAUMONT     77708
# 26987     4466    TX  Jefferson (County)           BEAUMONT     77713
# 26988     4466    TX  Jefferson (County)         BEVIL OAKS     77713
# 26990     4466    TX  Jefferson (County)              CHINA     77713
# 26999     4466    TX  Jefferson (County)               NOME     77769
#
#        Valid Registrations Average FEMA Inspected Damage  Total Inspected  \
# 25394                    1                             0                1
# 25678                   68                      3033.252               45
# 25276                   24                   1849.915833               24
# 25277                   11                       750.054               10
# 25369                    5                      2915.804                5
# ...                    ...                           ...              ...
# 26986                   65                          $588               54
# 26987                  259                        $8,689              219
# 26988                   10                       $11,237               10
# 26990                    1                          $440                1
# 26999                    1                            $0                1
#
#       Total Damage  No FEMA Inspected Damage  ...  \
# 25394            0                         1  ...
# 25678      136,496                         4  ...
# 25276       44,398                         3  ...
# 25277        7,501                         3  ...
# 25369       14,579                         1  ...
# ...            ...                       ...  ...
# 26986      $31,730                        25  ...
# 26987   $1,902,879                        38  ...
# 26988     $112,374                         1  ...
# 26990         $440                         0  ...
# 26999           $0                         1  ...
#
#        Approved for FEMA Assistance  Total Approved IHP Amount  \
# 25394                            $0                         $0
# 25678                           $30                    $81,328
# 25276                           $15                    $33,529
# 25277                            $4                     $5,889
# 25369                            $4                    $17,365
# ...                             ...                        ...
# 26986                             7                    $15,725
# 26987                           127                   $654,432
# 26988                             6                    $24,691
# 26990                             0                         $0
# 26999                             0                         $0
#
#       Repair/Replace Amount Rental Amount Other Needs Amount  \
# 25394                    $0            $0                 $0
# 25678               $58,458       $21,910               $960
# 25276               $31,899        $1,630                 $0
# 25277                $5,889            $0                 $0
# 25369                $7,186       $10,179                 $0
# ...                     ...           ...                ...
# 26986                $4,821        $7,034             $3,870
# 26987              $425,926      $196,162            $32,344
# 26988               $11,133        $9,572             $3,987
# 26990                    $0            $0                 $0
# 26999                    $0            $0                 $0
#
#       Approved between $1 and $10,000 Approved between $10,001 and $25,000  \
# 25394                               0                                    0
# 25678                             $30                                    0
# 25276                             $15                                    0
# 25277                              $4                                    0
# 25369                              $3                                   $1
# ...                               ...                                  ...
# 26986                               7                                    0
# 26987                             105                                   21
# 26988                               5                                    1
# 26990                               0                                    0
# 26999                               0                                    0
#
#       Approved between $25,001 and Max Total Max Grants  \
# 25394                                0               $0
# 25678                                0               $0
# 25276                                0               $0
# 25277                                0               $0
# 25369                                0               $0
# ...                                ...              ...
# 26986                                0                0
# 26987                                1                0
# 26988                                0                0
# 26990                                0                0
# 26999                                0                0
#
#                             address
# 25394       4116, IL, Cook (County)
# 25678       4116, IL, Lake (County)
# 25276       4116, IL, Cook (County)
# 25277       4116, IL, Cook (County)
# 25369       4116, IL, Cook (County)
# ...                             ...
# 26986  4466, TX, Jefferson (County)
# 26987  4466, TX, Jefferson (County)
# 26988  4466, TX, Jefferson (County)
# 26990  4466, TX, Jefferson (County)
# 26999  4466, TX, Jefferson (County)
#
# [28341 rows x 24 columns]

# %%
# Import "Renters Assistance" spreadsheet
renter_assist = './data/FEMA_Housing_Assistance_Renters.csv'
RA_df = pd.read_csv(renter_assist, low_memory=False, thousands = ',')
RAt_df = RA_df.sort_values(["Disaster", "Zip Code"])
RAt_df

# Only include inputs that can be summed or are part of the grouping
RAt_df["Disaster"] = RAt_df["Disaster"].astype(str)
RAt_df["address"] = RAt_df["Disaster"] + ', ' + RAt_df["State"] + ', ' + RAt_df["County"]

output_data_file2 = './data/FEMA_Housing_Assistance_Renters2.csv'
RAt_df.to_csv(output_data_file2, index=False, header=True)
RAt_df
# Out:
#       Disaster State              County               City  Zip Code  \
# 20426     4116    IL       Lake (County)            ANTIOCH     60002
# 20122     4116    IL       Cook (County)  ARLINGTON HEIGHTS     60004
# 20123     4116    IL       Cook (County)  ARLINGTON HEIGHTS     60005
# 20206     4116    IL       Cook (County)  ELK GROVE VILLAGE     60007
# 20284     4116    IL       Cook (County)    ROLLING MEADOWS     60008
# ...        ...   ...                 ...                ...       ...
# 21400     4466    TX  Jefferson (County)           BEAUMONT     77706
# 21401     4466    TX  Jefferson (County)           BEAUMONT     77707
# 21402     4466    TX  Jefferson (County)           BEAUMONT     77708
# 21245     4466    TX     Harris (County)           BEAUMONT     77713
# 21403     4466    TX  Jefferson (County)           BEAUMONT     77713
#
#        Valid Registrations  Total Inspected  Inspected with No Damage  \
# 20426                   10                7                         3
# 20122                    5                4                         4
# 20123                    2                1                         1
# 20206                    3                3                         2
# 20284                    3                3                         3
# ...                    ...              ...                       ...
# 21400                  241              151                       119
# 21401                  469              352                       174
# 21402                  133               92                        90
# 21245                    1                0                         0
# 21403                   82               55                        37
#
#        Total with Moderate Damage  Total with Major Damage  ...  \
# 20426                           4                        0  ...
# 20122                           0                        0  ...
# 20123                           0                        0  ...
# 20206                           1                        0  ...
# 20284                           0                        0  ...
# ...                           ...                      ...  ...
# 21400                          32                        0  ...
# 21401                         178                        0  ...
# 21402                           2                        0  ...
# 21245                           0                        0  ...
# 21403                          17                        1  ...
#
#        Approved for FEMA Assistance  Total Approved IHP Amount  \
# 20426                             4                    $11,231
# 20122                             0                         $0
# 20123                             1                       $260
# 20206                             2                     $3,619
# 20284                             1                     $2,590
# ...                             ...                        ...
# 21400                            40                    $62,725
# 21401                           181                   $568,172
# 21402                            11                    $19,588
# 21245                             0                         $0
# 21403                            28                    $60,184
#
#       Repair/Replace Amount Rental Amount Other Needs Amount  \
# 20426                    $0        $9,318             $1,913
# 20122                    $0            $0                 $0
# 20123                    $0            $0               $260
# 20206                    $0        $1,932             $1,687
# 20284                    $0        $1,932               $658
# ...                     ...           ...                ...
# 21400                    $0       $54,078             $8,647
# 21401                    $0      $266,277           $301,895
# 21402                    $0        $4,460            $15,128
# 21245                    $0            $0                 $0
# 21403                    $0       $28,704            $31,480
#
#       Approved between $1 and $10,000  Approved between $10,001 and $25,000  \
# 20426                               4                                     0
# 20122                               0                                     0
# 20123                               1                                     0
# 20206                               2                                     0
# 20284                               1                                     0
# ...                               ...                                   ...
# 21400                              40                                     0
# 21401                             180                                     1
# 21402                              11                                     0
# 21245                               0                                     0
# 21403                              28                                     0
#
#        Approved between $25,001 and Max  Total Max Grants  \
# 20426                                 0                 0
# 20122                                 0                 0
# 20123                                 0                 0
# 20206                                 0                 0
# 20284                                 0                 0
# ...                                 ...               ...
# 21400                                 0                 0
# 21401                                 0                 0
# 21402                                 0                 0
# 21245                                 0                 0
# 21403                                 0                 0
#
#                             address
# 20426       4116, IL, Lake (County)
# 20122       4116, IL, Cook (County)
# 20123       4116, IL, Cook (County)
# 20206       4116, IL, Cook (County)
# 20284       4116, IL, Cook (County)
# ...                             ...
# 21400  4466, TX, Jefferson (County)
# 21401  4466, TX, Jefferson (County)
# 21402  4466, TX, Jefferson (County)
# 21245     4466, TX, Harris (County)
# 21403  4466, TX, Jefferson (County)
#
# [22733 rows x 21 columns]

# %%
# Import "Disaster Declarations" spreadsheet
disaster_declare = './data/DisasterDeclarationsSummaries.csv'
DDt_df = pd.read_csv(disaster_declare, low_memory=False)

# Only include inputs that can be summed or are part of the grouping
DDt_df["disasterNumber"] = DDt_df["disasterNumber"].astype(str)
DDt_df["address"] = DDt_df["disasterNumber"] + ', ' + DDt_df["state"] + ', ' + DDt_df["designatedArea"]

DDt_df = DDt_df.sort_values("address")

output_data_file3 = './data/DisasterDeclarationsSummaries2.csv'
DDt_df.to_csv(output_data_file3, index=False, header=True)
DDt_df
# Note the minimum and maximum disaster Numbers
# Out:
#       femaDeclarationString disasterNumber state declarationType  \
# 6                   DR-1-GA              1    GA              DR
# 187               DR-100-MO            100    MO              DR
# 10192            DR-1000-KS           1000    KS              DR
# 8085             DR-1000-KS           1000    KS              DR
# 9140             DR-1000-KS           1000    KS              DR
# ...                     ...            ...   ...             ...
# 10961             DR-999-SD            999    SD              DR
# 11050             DR-999-SD            999    SD              DR
# 10303             DR-999-SD            999    SD              DR
# 9815              DR-999-SD            999    SD              DR
# 10041             DR-999-SD            999    SD              DR
#
#                 declarationDate  fyDeclared     incidentType  \
# 6      1953-05-02T04:00:00.000Z        1953          Tornado
# 187    1960-04-20T05:00:00.000Z        1960            Flood
# 10192  1993-07-22T04:00:00.000Z        1993            Flood
# 8085   1993-07-22T04:00:00.000Z        1993            Flood
# 9140   1993-07-22T04:00:00.000Z        1993            Flood
# ...                         ...         ...              ...
# 10961  1993-07-19T04:00:00.000Z        1993  Severe Storm(s)
# 11050  1993-07-19T04:00:00.000Z        1993  Severe Storm(s)
# 10303  1993-07-19T04:00:00.000Z        1993  Severe Storm(s)
# 9815   1993-07-19T04:00:00.000Z        1993  Severe Storm(s)
# 10041  1993-07-19T04:00:00.000Z        1993  Severe Storm(s)
#
#                           declarationTitle  ihProgramDeclared  \
# 6                                  TORNADO                  0
# 187                                 FLOODS                  0
# 10192             SEVERE STORMS & FLOODING                  0
# 8085              SEVERE STORMS & FLOODING                  0
# 9140              SEVERE STORMS & FLOODING                  0
# ...                                    ...                ...
# 10961  SEVERE STORMS, TORNADOES & FLOODING                  0
# 11050  SEVERE STORMS, TORNADOES & FLOODING                  0
# 10303  SEVERE STORMS, TORNADOES & FLOODING                  0
# 9815   SEVERE STORMS, TORNADOES & FLOODING                  0
# 10041  SEVERE STORMS, TORNADOES & FLOODING                  0
#
#        iaProgramDeclared  ...           incidentEndDate  disasterCloseoutDate  \
# 6                      1  ...  1953-05-02T04:00:00.000Z                   NaN
# 187                    1  ...  1960-04-20T05:00:00.000Z                   NaN
# 10192                  1  ...  1993-10-05T04:00:00.000Z                   NaN
# 8085                   1  ...  1993-10-05T04:00:00.000Z                   NaN
# 9140                   1  ...  1993-10-05T04:00:00.000Z                   NaN
# ...                  ...  ...                       ...                   ...
# 10961                  1  ...  1993-09-10T04:00:00.000Z                   NaN
# 11050                  1  ...  1993-09-10T04:00:00.000Z                   NaN
# 10303                  1  ...  1993-09-10T04:00:00.000Z                   NaN
# 9815                   1  ...  1993-09-10T04:00:00.000Z                   NaN
# 10041                  1  ...  1993-09-10T04:00:00.000Z                   NaN
#
#       fipsStateCode fipsCountyCode placeCode     designatedArea  \
# 6                13              0         0          Statewide
# 187              29              0         0          Statewide
# 10192            20              5     99005  Atchison (County)
# 8085             20              9     99009    Barton (County)
# 9140             20             13     99013     Brown (County)
# ...             ...            ...       ...                ...
# 10961            46            115     99115     Spink (County)
# 11050            46            125     99125    Turner (County)
# 10303            46            127     99127     Union (County)
# 9815             46            135     99135   Yankton (County)
# 10041            46            137     99137   Ziebach (County)
#
#        declarationRequestNumber                              hash  \
# 6                         53013  2f28952448e0a666d367ca3f854c81ec
# 187                       60017  48cf1a138847518821386b2d4d70f498
# 10192                     93035  a741b21def370ae1df90eb40f63acbdb
# 8085                      93035  622f5282effdb573777f0f12ae75632a
# 9140                      93035  5e6d554fb696daaaf13379191ac2ede4
# ...                         ...                               ...
# 10961                     93034  b47ec4338b486c41052891702f191c25
# 11050                     93034  3b3a1130ecc806ccb6a5cdf8407d5a37
# 10303                     93034  1c1747f0d25f10dce2d10faf572b4e6e
# 9815                      93034  8a0ac4e4ad5e01399299dd0accbb8a2c
# 10041                     93034  b497d933a9298c63419569f2141447bb
#
#                     lastRefresh                      address
# 6      2019-07-26T18:49:32.242Z             1, GA, Statewide
# 187    2019-07-26T18:49:32.241Z           100, MO, Statewide
# 10192  2019-07-26T18:49:40.438Z  1000, KS, Atchison (County)
# 8085   2019-07-26T18:49:40.509Z    1000, KS, Barton (County)
# 9140   2019-07-26T18:49:40.510Z     1000, KS, Brown (County)
# ...                         ...                          ...
# 10961  2019-07-26T18:49:40.509Z      999, SD, Spink (County)
# 11050  2019-07-26T18:49:40.513Z     999, SD, Turner (County)
# 10303  2019-07-26T18:49:40.512Z      999, SD, Union (County)
# 9815   2019-07-26T18:49:40.441Z    999, SD, Yankton (County)
# 10041  2019-07-26T18:49:40.510Z    999, SD, Ziebach (County)
#
# [51113 rows x 23 columns]
